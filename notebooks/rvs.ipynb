# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
t = Table.read('../data/harps_rvs.csv')
t['rv'] -= np.median(t['rv'])

# %%
plt.scatter(t['bjd'], t['rv'], c=t['bis'])
plt.clim([-0.04,0.01])
plt.colorbar(label='BIS');

# %%
plt.scatter(t['rv'], t['bis']);
